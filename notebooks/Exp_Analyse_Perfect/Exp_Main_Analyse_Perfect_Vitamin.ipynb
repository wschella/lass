# %%
import logging

# autopep8: off
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

from lass.test import test
from lass.log_handling import LogLoaderArgs
# autopep8: on


def main():
    logging.basicConfig(
        level=logging.INFO,
        format='[%(asctime)s][%(levelname)s][%(module)s/%(funcName)s]: %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'
    )
    return test(
        data_args=LogLoaderArgs(
            logdir="../artifacts/logs",
            # tasks="paper-full",
            tasks=["vitaminc_fact_verification"],
            model_families=["BIG-G T=0"],
            model_sizes=["128b"],
            # model_sizes=["2m"],
            shots=[0],
            query_types=["multiple_choice"],
        ),
        model_name="microsoft/deberta-v3-base",
        split="instance",
        model_loc="../artifacts/assessors/reference-models/deberta-reference-bs16*2-0sh-instance-split-10241537/checkpoint-4000",
        per_task=True,
    )

results = main()
# Out:
# [2023-05-09 17:50:20][INFO][test/test]: Starting data loading
# [2023-05-09 17:50:21][INFO][test/test]: Loaded data.
# [2023-05-09 17:50:21][INFO][pipeline/binarize]: Dropped 0 samples with non-binary correctness
# [2023-05-09 17:50:21][INFO][pipeline/clean]: Dropped 0 samples with faulty targets
# {'metrics': {'conf-absolute': {'acc': {'test': 0.8829268292682927,
#                                        'train': 0.8791208791208791},
#                                'balanced_acc': {'test': 0.5, 'train': 0.5},
#                                'bs': {'test': 0.10875036449075261,
#                                       'train': 0.11315139579595622},
#                                'bs_dcr': {'test': 0.0023393691103797826,
#                                           'train': 0.00019948100606627384},
#                                'bs_mcb': {'test': 0.007722690174600574,
#                                           'train': 0.007083517787410731},
#                                'bs_unc': {'test': 0.10336704342653182,
#                                           'train': 0.10626735901461176},
#                                'roc_auc': {'test': 0.44337016574585636,
#                                            'train': 0.4289983164983165}},
#              'conf-normalized': {'acc': {'test': 0.11707317073170732,
#                                          'train': 0.12087912087912088},
#                                  'balanced_acc': {'test': 0.5, 'train': 0.5},
#                                  'bs': {'test': 0.7875698521421595,
#                                         'train': 0.7834763677057752},
#                                  'bs_dcr': {'test': 0.0016353361094586238,
#                                             'train': 0.000581256776336761},
#                                  'bs_mcb': {'test': 0.6858381448250863,
#                                             'train': 0.6777902654675002},
#                                  'bs_unc': {'test': 0.10336704342653182,
#                                             'train': 0.10626735901461176},
#                                  'roc_auc': {'test': 0.44613259668508287,
#                                              'train': 0.5022937710437712}},
#              'task-acc': {'test': 0.11707317073170732,
#                           'train': 0.12087912087912088}},
#  'stats': {'n_instances': {'test': 205, 'train': 819},
#            'n_instances_nonbinary': {'test': 0, 'train': 0},
#            'n_tasks': {'test': 1, 'train': 1}}}
#                                                  input  \
# 525  Based only on the information contained in a b...
#
#                     targets  \
# 525  [True, False, Neither]
#
#                                                 scores  \
# 525  [-7.3643293380737305, -8.257465362548828, -3.1...
#
#                              target_values  correct  \
# 525  {'False': 0, 'Neither': 0, 'True': 1}        0
#
#                                        absolute_scores  \
# 525  [-7.3643293380737305, -8.257465362548828, -3.1...
#
#                                      normalized_scores  \
# 525  [-4.198119163513184, -5.091255187988281, -0.02...
#
#                                                metrics model_name  \
# 525  {'calibration_multiple_choice_brier_score': 0....       128b
#
#     model_family                        task  shots  n_targets  \
# 525    BIG-G T=0  vitaminc_fact_verification      0          3
#
#      conf_normalized  conf_absolute
# 525         0.978826        0.04127
# /home/wout/Code/pp/lass/.env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/wout/Code/pp/lass/.env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# loading configuration file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/config.json from cache at /home/wout/.cache/huggingface/transformers/e6f9db57345f0f60c9f837fa97bcb27b1ed31e99feb33d732d7d8c80cb8f8459.de97182a9f32a68819030ba8f3f6ff2ba47276be3864425925523202f54cc79c
# Model config DebertaV2Config {
#   "_name_or_path": "microsoft/deberta-v3-base",
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta-v2",
#   "norm_rel_ebd": "layer_norm",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": [
#     "p2c",
#     "c2p"
#   ],
#   "position_biased_input": false,
#   "position_buckets": 256,
#   "relative_attention": true,
#   "share_att_key": true,
#   "transformers_version": "4.21.3",
#   "type_vocab_size": 0,
#   "vocab_size": 128100
# }
#
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/spm.model from cache at /home/wout/.cache/huggingface/transformers/ec748fd4f03d0e5a2d5d56dff01e6dd733f23c67105cd54a9910f9d711870253.0abaeacf7287ee8ba758fec15ddfb4bb6c697bb1a8db272725f8aa633501787a
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/tokenizer_config.json from cache at /home/wout/.cache/huggingface/transformers/967a4d63eb35950cfd24a9e335906419009f32940fa2ba1b73e7ba032628c38d.df5a7f41459442f66bec27ac9352bba694cde109855024b3ae61be2f5734ee9a
# loading configuration file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/config.json from cache at /home/wout/.cache/huggingface/transformers/e6f9db57345f0f60c9f837fa97bcb27b1ed31e99feb33d732d7d8c80cb8f8459.de97182a9f32a68819030ba8f3f6ff2ba47276be3864425925523202f54cc79c
# Model config DebertaV2Config {
#   "_name_or_path": "microsoft/deberta-v3-base",
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta-v2",
#   "norm_rel_ebd": "layer_norm",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": [
#     "p2c",
#     "c2p"
#   ],
#   "position_biased_input": false,
#   "position_buckets": 256,
#   "relative_attention": true,
#   "share_att_key": true,
#   "transformers_version": "4.21.3",
#   "type_vocab_size": 0,
#   "vocab_size": 128100
# }
#
# Adding [MASK] to the vocabulary
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# loading configuration file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/config.json from cache at /home/wout/.cache/huggingface/transformers/e6f9db57345f0f60c9f837fa97bcb27b1ed31e99feb33d732d7d8c80cb8f8459.de97182a9f32a68819030ba8f3f6ff2ba47276be3864425925523202f54cc79c
# Model config DebertaV2Config {
#   "_name_or_path": "microsoft/deberta-v3-base",
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta-v2",
#   "norm_rel_ebd": "layer_norm",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": [
#     "p2c",
#     "c2p"
#   ],
#   "position_biased_input": false,
#   "position_buckets": 256,
#   "relative_attention": true,
#   "share_att_key": true,
#   "transformers_version": "4.21.3",
#   "type_vocab_size": 0,
#   "vocab_size": 128100
# }
#
# /home/wout/Code/pp/lass/.env/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:434: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [2023-05-09 17:50:26][WARNING][fingerprint/update_fingerprint]: Parameter 'function'=<function tokenize.<locals>.tokenize_function at 0x7f49b09f4f70> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the test set don't have a corresponding argument in `DebertaV2ForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DebertaV2ForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 205
#   Batch size = 8
#     <div>
#
#       <progress value='3' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3/26 00:00 < 00:02, 9.09 it/s]
#     </div>
# {'text': 'Based only on the information contained in a brief quote from Wikipedia, answer whether the related claim is True, False or Neither. Use Neither when the Wikipedia quote does not provide the necessary information to resolve the question.\n\n\nPassage: Chris Benoit: Christopher Michael Benoit ( June 21 , 2007 to June 24 , 2019 ) was a Canadian professional wrestler .\nClaim: Chris Benoit date of birth occurred in June 2007 .\nTrue, False, or Neither? ', 'label': 0}
# loading configuration file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/config.json from cache at /home/wout/.cache/huggingface/transformers/e6f9db57345f0f60c9f837fa97bcb27b1ed31e99feb33d732d7d8c80cb8f8459.de97182a9f32a68819030ba8f3f6ff2ba47276be3864425925523202f54cc79c
# Model config DebertaV2Config {
#   "_name_or_path": "microsoft/deberta-v3-base",
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta-v2",
#   "norm_rel_ebd": "layer_norm",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": [
#     "p2c",
#     "c2p"
#   ],
#   "position_biased_input": false,
#   "position_buckets": 256,
#   "relative_attention": true,
#   "share_att_key": true,
#   "transformers_version": "4.21.3",
#   "type_vocab_size": 0,
#   "vocab_size": 128100
# }
#
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/spm.model from cache at /home/wout/.cache/huggingface/transformers/ec748fd4f03d0e5a2d5d56dff01e6dd733f23c67105cd54a9910f9d711870253.0abaeacf7287ee8ba758fec15ddfb4bb6c697bb1a8db272725f8aa633501787a
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/tokenizer_config.json from cache at /home/wout/.cache/huggingface/transformers/967a4d63eb35950cfd24a9e335906419009f32940fa2ba1b73e7ba032628c38d.df5a7f41459442f66bec27ac9352bba694cde109855024b3ae61be2f5734ee9a
# loading configuration file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/config.json from cache at /home/wout/.cache/huggingface/transformers/e6f9db57345f0f60c9f837fa97bcb27b1ed31e99feb33d732d7d8c80cb8f8459.de97182a9f32a68819030ba8f3f6ff2ba47276be3864425925523202f54cc79c
# Model config DebertaV2Config {
#   "_name_or_path": "microsoft/deberta-v3-base",
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta-v2",
#   "norm_rel_ebd": "layer_norm",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": [
#     "p2c",
#     "c2p"
#   ],
#   "position_biased_input": false,
#   "position_buckets": 256,
#   "relative_attention": true,
#   "share_att_key": true,
#   "transformers_version": "4.21.3",
#   "type_vocab_size": 0,
#   "vocab_size": 128100
# }
#
# Adding [MASK] to the vocabulary
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# loading configuration file https://huggingface.co/microsoft/deberta-v3-base/resolve/main/config.json from cache at /home/wout/.cache/huggingface/transformers/e6f9db57345f0f60c9f837fa97bcb27b1ed31e99feb33d732d7d8c80cb8f8459.de97182a9f32a68819030ba8f3f6ff2ba47276be3864425925523202f54cc79c
# Model config DebertaV2Config {
#   "_name_or_path": "microsoft/deberta-v3-base",
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta-v2",
#   "norm_rel_ebd": "layer_norm",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": [
#     "p2c",
#     "c2p"
#   ],
#   "position_biased_input": false,
#   "position_buckets": 256,
#   "relative_attention": true,
#   "share_att_key": true,
#   "transformers_version": "4.21.3",
#   "type_vocab_size": 0,
#   "vocab_size": 128100
# }
#
# /home/wout/Code/pp/lass/.env/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:434: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the test set don't have a corresponding argument in `DebertaV2ForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DebertaV2ForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 205
#   Batch size = 8
#     <div>
#
#       <progress value='1' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 1/26 : < :]
#     </div>

# %%
import pandas as pd
import numpy as np

# %%
df: pd.DataFrame = results["test"] # type: ignore

# %%
df
# Out:
#                                                   input  \
# 1     Based only on the information contained in a b...
# 4     Based only on the information contained in a b...
# 13    Based only on the information contained in a b...
# 14    Based only on the information contained in a b...
# 20    Based only on the information contained in a b...
# ...                                                 ...
# 1000  Based only on the information contained in a b...
# 1004  Based only on the information contained in a b...
# 1006  Based only on the information contained in a b...
# 1016  Based only on the information contained in a b...
# 1020  Based only on the information contained in a b...
#
#                      targets  \
# 1     [True, False, Neither]
# 4     [True, False, Neither]
# 13    [True, False, Neither]
# 14    [True, False, Neither]
# 20    [True, False, Neither]
# ...                      ...
# 1000  [True, False, Neither]
# 1004  [True, False, Neither]
# 1006  [True, False, Neither]
# 1016  [True, False, Neither]
# 1020  [True, False, Neither]
#
#                                                  scores  \
# 1     [-5.599615573883057, -6.96262264251709, -2.888...
# 4     [-5.272380828857422, -6.670485496520996, -3.36...
# 13    [-7.029752731323242, -8.155021667480469, -3.24...
# 14    [-7.862296104431152, -8.291386604309082, -4.47...
# 20    [-7.968445301055908, -9.256637573242188, -4.80...
# ...                                                 ...
# 1000  [-6.509408950805664, -7.98386812210083, -2.987...
# 1004  [-6.018407344818115, -7.520390033721924, -2.80...
# 1006  [-6.968756675720215, -7.990128517150879, -3.16...
# 1016  [-6.650867462158203, -7.543581008911133, -3.33...
# 1020  [-7.22921085357666, -7.943737983703613, -2.921...
#
#                               target_values  correct  \
# 1     {'False': 0, 'Neither': 0, 'True': 1}        0
# 4     {'False': 0, 'Neither': 1, 'True': 0}        1
# 13    {'False': 0, 'Neither': 0, 'True': 1}        0
# 14    {'False': 0, 'Neither': 0, 'True': 1}        0
# 20    {'False': 0, 'Neither': 0, 'True': 1}        0
# ...                                     ...      ...
# 1000  {'False': 1, 'Neither': 0, 'True': 0}        0
# 1004  {'False': 0, 'Neither': 0, 'True': 1}        0
# 1006  {'False': 1, 'Neither': 0, 'True': 0}        0
# 1016  {'False': 0, 'Neither': 0, 'True': 1}        0
# 1020  {'False': 0, 'Neither': 0, 'True': 1}        0
#
#                                         absolute_scores  \
# 1     [-5.599615573883057, -6.96262264251709, -2.888...
# 4     [-5.272380828857422, -6.670485496520996, -3.36...
# 13    [-7.029752731323242, -8.155021667480469, -3.24...
# 14    [-7.862296104431152, -8.291386604309082, -4.47...
# 20    [-7.968445301055908, -9.256637573242188, -4.80...
# ...                                                 ...
# 1000  [-6.509408950805664, -7.98386812210083, -2.987...
# 1004  [-6.018407344818115, -7.520390033721924, -2.80...
# 1006  [-6.968756675720215, -7.990128517150879, -3.16...
# 1016  [-6.650867462158203, -7.543581008911133, -3.33...
# 1020  [-7.22921085357666, -7.943737983703613, -2.921...
#
#                                       normalized_scores  \
# 1     [-2.790914297103882, -4.153921127319336, -0.08...
# 4     [-2.081430435180664, -3.4795351028442383, -0.1...
# 13    [-3.8112952709198, -4.9365644454956055, -0.029...
# 14    [-3.437802314758301, -3.8668928146362305, -0.0...
# 20    [-3.2138733863830566, -4.502065658569336, -0.0...
# ...                                                 ...
# 1000  [-3.557363510131836, -5.031822681427002, -0.03...
# 1004  [-3.2566850185394287, -4.758667945861816, -0.0...
# 1006  [-3.832761764526367, -4.854133605957031, -0.02...
# 1016  [-3.3610987663269043, -4.253812313079834, -0.0...
# 1020  [-4.327615737915039, -5.042142868041992, -0.01...
#
#                                                 metrics model_name  \
# 1     {'calibration_multiple_choice_brier_score': 0....       128b
# 4     {'calibration_multiple_choice_brier_score': 0....       128b
# 13    {'calibration_multiple_choice_brier_score': 0....       128b
# 14    {'calibration_multiple_choice_brier_score': 0....       128b
# 20    {'calibration_multiple_choice_brier_score': 0....       128b
# ...                                                 ...        ...
# 1000  {'calibration_multiple_choice_brier_score': 0....       128b
# 1004  {'calibration_multiple_choice_brier_score': 0....       128b
# 1006  {'calibration_multiple_choice_brier_score': 0....       128b
# 1016  {'calibration_multiple_choice_brier_score': 0....       128b
# 1020  {'calibration_multiple_choice_brier_score': 0....       128b
#
#      model_family                        task  shots  n_targets  \
# 1       BIG-G T=0  vitaminc_fact_verification      0          3
# 4       BIG-G T=0  vitaminc_fact_verification      0          3
# 13      BIG-G T=0  vitaminc_fact_verification      0          3
# 14      BIG-G T=0  vitaminc_fact_verification      0          3
# 20      BIG-G T=0  vitaminc_fact_verification      0          3
# ...           ...                         ...    ...        ...
# 1000    BIG-G T=0  vitaminc_fact_verification      0          3
# 1004    BIG-G T=0  vitaminc_fact_verification      0          3
# 1006    BIG-G T=0  vitaminc_fact_verification      0          3
# 1016    BIG-G T=0  vitaminc_fact_verification      0          3
# 1020    BIG-G T=0  vitaminc_fact_verification      0          3
#
#       conf_normalized  conf_absolute
# 1            0.922932       0.055637
# 4            0.844427       0.034734
# 13           0.970701       0.038844
# 14           0.946942       0.011345
# 20           0.948713       0.008171
# ...               ...            ...
# 1000         0.964959       0.050402
# 1004         0.952907       0.060207
# 1006         0.970554       0.042177
# 1016         0.951093       0.035440
# 1020         0.980341       0.053856
#
# [205 rows x 15 columns]

# %%
subject_preds = np.array(df.scores.values.tolist())
subject_preds.argmax(axis=1)
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2])

# %%
df.query("correct == 0").target_values.value_counts()
# Out:
# {'False': 0, 'Neither': 0, 'True': 1}    113
# {'False': 1, 'Neither': 0, 'True': 0}     68
# Name: target_values, dtype: int64

# %%
df.query("correct == 1").target_values.value_counts()
# Out:
# {'False': 0, 'Neither': 1, 'True': 0}    24
# Name: target_values, dtype: int64

# %%
results["logits"].argmax(axis=1)

j = df["correct"].to_frame()
j["asss"] = results["logits"].argmax(axis=1)
j.query("correct != asss")
# Out:
#      correct  asss
# 4          1     0
# 47         1     0
# 87         1     0
# 95         1     0
# 295        1     0
# 313        1     0
# 337        1     0
# 397        1     0
# 413        1     0
# 427        1     0
# 474        1     0
# 540        1     0
# 553        1     0
# 686        1     0
# 701        1     0
# 719        1     0
# 725        1     0
# 812        1     0
# 815        1     0
# 860        1     0
# 871        1     0
# 931        1     0
# 955        1     0
# 957        1     0

# %%
results["metrics"]
# Out:
# {'test_loss': 0.33332112431526184,
#  'test_conf_distribution_accuracy': 0.8829268292682927,
#  'test_conf_distribution_precision': 0.0,
#  'test_conf_distribution_recall': 0.0,
#  'test_conf_distribution_f1': 0.0,
#  'test_conf_distribution_roc_auc': 0.5,
#  'test_conf_distribution_bs': 0.10336704342653182,
#  'test_conf_distribution_bs_mcb': 0.0,
#  'test_conf_distribution_bs_dsc': 0.0,
#  'test_conf_distribution_bs_unc': 0.10336704342653182,
#  'test_conf_distribution_balanced_accuracy': 0.5,
#  'test_conf_absolute_accuracy': 0.8829268292682927,
#  'test_conf_absolute_precision': 0.0,
#  'test_conf_absolute_recall': 0.0,
#  'test_conf_absolute_f1': 0.0,
#  'test_conf_absolute_roc_auc': 0.44337016574585636,
#  'test_conf_absolute_bs': 0.10875036449075261,
#  'test_conf_absolute_bs_mcb': 0.007722690174600574,
#  'test_conf_absolute_bs_dsc': 0.0023393691103797826,
#  'test_conf_absolute_bs_unc': 0.10336704342653182,
#  'test_conf_absolute_balanced_accuracy': 0.5,
#  'test_conf_normalized_accuracy': 0.11707317073170732,
#  'test_conf_normalized_precision': 0.11707317073170732,
#  'test_conf_normalized_recall': 1.0,
#  'test_conf_normalized_f1': 0.2096069868995633,
#  'test_conf_normalized_roc_auc': 0.44613259668508287,
#  'test_conf_normalized_bs': 0.7875698521421595,
#  'test_conf_normalized_bs_mcb': 0.6858381448250863,
#  'test_conf_normalized_bs_dsc': 0.0016353361094586238,
#  'test_conf_normalized_bs_unc': 0.10336704342653182,
#  'test_conf_normalized_balanced_accuracy': 0.5,
#  'test_accuracy': 0.8829268292682927,
#  'test_precision': 0.0,
#  'test_recall': 0.0,
#  'test_f1': 0.0,
#  'test_roc_auc': 0.850828729281768,
#  'test_bs': 0.09732716375523706,
#  'test_bs_mcb': 0.016678052021520284,
#  'test_bs_dsc': 0.022717931692815038,
#  'test_bs_unc': 0.10336704342653182,
#  'test_balanced_accuracy': 0.5,
#  'test_runtime': 2.8455,
#  'test_samples_per_second': 72.045,
#  'test_steps_per_second': 9.137}
